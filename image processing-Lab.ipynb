# %%
import numpy as np
import matplotlib.pyplot as py
# %matplotlib inline

# %% [markdown]
# use imgread to load the image python.png to numpy array

# %%
img = py.imread('python.png')

# %% [markdown]
# Display the image

# %%
py.imshow(img)

# %% [markdown]
# Display the image array shape

# %%
img.shape
# Out:
# (1000, 1000, 4)

# %% [raw]
# Write a function rgb2gray To convert the image to grayscale
#
# you need to calculate for each pixel:
#
# R * 0.299  +  G * 0.587 + B * 0.144
#
# Use dot product

# %% [markdown]
# Test the function on the above image

# %% [markdown]
# Display the image , use cmap='gray'

# %%
py.imshow(img, cmap='gray')

# %% [markdown]
# Repeat the task with the file angular.png

# %%
img = py.imread('angular.png')
py.imshow(img)

# %% [markdown]
# use the package skimage

# %%
import skimage
from skimage import data, io

# %% [markdown]
# display the image

# %%
io.imshow(img)

# %% [markdown]
# display the image shape

# %%
img1.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# use the above function to convert to RGB

# %%
from PIL import Image
pilImage = Image.open('angular.png')
pilImage.mode
# Out:
# 'RGB'

# %% [markdown]
# # using scipy

# %% [markdown]
# Use scipy signal package to apply med filter on the image

# %%
from scipy import ndimage, misc

# %%
result = ndimage.median_filter(img, size=20)
py.imshow(result)

# %% [markdown]
# Use scikit-image to convert the (PNG) image file to RGB

# %%
img = io.imread('angular.png', True)
py.imshow(img)
